# %% [markdown]
# # Merging All Datasets in One Graph

# %% [markdown]
# As usual, importing the needed libraries is the first step

# %%
import plotly.plotly as py
import pandas as pd
import numpy as np
#import cufflinks as cf 
#cf.go_offline()
import plotly.graph_objs as go
from plotly.offline import *
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode( connected = True )
import urllib.request
import json
from pandas.io.json import json_normalize
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## A. Reading Data

# %%
#Calling Live Data from API 
with urllib.request.urlopen("https://www.numbeo.com/api/rankings_by_city_historical?api_key=aml7iv7ua8pnxo&section=1") as url:
    dataCostOfLiving = json.load(url)
    print(dataCostOfLiving)
# Out:
# {'2012': [{'country': 'Norway', 'city_name': 'Trondheim', 'cpi_and_rent_index': 142.213775943675, 'rent_index': 59.1643129137286, 'purchasing_power_incl_rent_index': 67.0079542854664, 'restaurant_price_index': 160.230357098712, 'groceries_index': 193.936491910627, 'city_id': 5970, 'cpi_index': 188.910503280187}, {'country': 'Norway', 'city_name': 'Stavanger', 'cpi_and_rent_index': 137.762589838008, 'rent_index': 78.0809547405555, 'purchasing_power_incl_rent_index': 78.4958678639918, 'restaurant_price_index': 201.163181235453, 'groceries_index': 147.735435337591, 'city_id': 7409, 'cpi_index': 171.32014625638}, {'country': 'Switzerland', 'city_name': 'Zurich', 'cpi_and_rent_index': 124.674876830621, 'rent_index': 74.5835847462938, 'purchasing_power_incl_rent_index': 142.77480774886, 'restaurant_price_index': 138.786508076975, 'groceries_index': 143.698374998437, 'city_id': 6379, 'cpi_index': 152.840012679265}, {'country': 'Norway', 'city_name': 'Oslo', 'cpi_and_rent_index': 117.969883353527, 'rent_index': 57.4001716029615, 'purchasing_power_incl_rent_index': 99.3103312032261, 'restaurant_price_index': 155.750221133386, 'groceries_index': 139.217948375871, 'city_id': 5968, 'cpi_index': 152.026784039896}, {'country': 'Switzerland', 'city_name': 'Geneva', 'cpi_and_rent_index': 122.060417132376, 'rent_index': 79.0542379934223, 'purchasing_power_incl_rent_index': 115.535628811331, 'restaurant_price_index': 135.252612796238, 'groceries_index': 138.950064728918, 'city_id': 6355, 'cpi_index': 146.241763377959}, {'country': 'Switzerland', 'city_name': 'Bern', 'cpi_and_rent_index': 111.849247621198, 'rent_index': 57.4414742833869, 'purchasing_power_incl_rent_index': 149.280925943767, 'restaurant_price_index': 103.591042417019, 'groceries_index': 126.781082071648, 'city_id': 6349, 'cpi_index': 142.441437670957}, {'country': 'Switzerland', 'city_name': 'Lucerne', 'cpi_and_rent_index': 115.649202722367, 'rent_index': 72.4500140011214, 'purchasing_power_incl_rent_index': 105.649040091501, 'restaurant_price_index': 95.7233003623885, 'groceries_index': 146.524056746342, 'city_id': 6361, 'cpi_index': 139.939073641184}, {'country': 'Australia', 'city_name': 'Perth', 'cpi_and_rent_index': 105.12642777465, 'rent_index': 43.7602888859123, 'purchasing_power_incl_rent_index': 125.080682252963, 'restaurant_price_index': 131.613239395752, 'groceries_index': 113.128220246582, 'city_id': 3579, 'cpi_index': 139.631140398121}, {'country': 'Norway', 'city_name': 'Bergen', 'cpi_and_rent_index': 108.984261256204, 'rent_index': 55.977303925531, 'purchasing_power_incl_rent_index': 97.0226801473306, 'restaurant_price_index': 130.233349762083, 'groceries_index': 135.463563823948, 'city_id': 5955, 'cpi_index': 138.788805958871}, {'country': 'Japan', 'city_name': 'Tokyo', 'cpi_and_rent_index': 120.905681224919, 'rent_index': 95.4310777455749, 'purchasing_power_incl_rent_index': 90.1430801177115, 'restaurant_price_index': 91.6797607616449, 'groceries_index': 120.422084052798, 'city_id': 4164, 'cpi_index': 135.22944165973}, {'country': 'Australia', 'city_name': 'Sydney', 'cpi_and_rent_index': 115.786253883598, 'rent_index': 86.2484691474659, 'purchasing_power_incl_rent_index': 97.2270858438158, 'restaurant_price_index': 110.975798658772, 'groceries_index': 121.112197163447, 'city_id': 3581, 'cpi_index': 132.394643987822}, {'country': 'Australia', 'city_name': 'Adelaide', 'cpi_and_rent_index': 99.9809932106132, 'rent_index': 47.3009783062388, 'purchasing_power_incl_rent_index': 112.19350055923, 'restaurant_price_index': 121.440633011029, 'groceries_index': 120.683478544687, 'city_id': 3561, 'cpi_index': 129.601706004215}, {'country': 'Monaco', 'city_name': 'Monaco', 'cpi_and_rent_index': 144.324183482344, 'rent_index': 173.084769510323, 'purchasing_power_incl_rent_index': 62.3024145730749, 'restaurant_price_index': 138.142812250159, 'groceries_index': 89.7962052143721, 'city_id': 7395, 'cpi_index': 128.152793628775}, {'country': 'Denmark', 'city_name': 'Copenhagen', 'c ...

# %%
# Reading Data
homelessness = pd.read_csv('2007-2016-Homelessnewss-USA.csv')
population =  pd.read_csv('Population-by-state.csv')
race = pd.read_excel('2015 Racial Data _ State.xls','raw_data.csv')

# %% [markdown]
# ## B. Cleaning data

# %% [markdown]
# ### (1) Population DataSet:

# %% [markdown]
#  Dropping and renaming columns

# %%
# Cleaning datasets 
# Begining with Population DataSet 
# 1. taking the first row and making it the header
population.columns = population.iloc[0]
# 2. removing the 0 row
population.drop(0,axis=0, inplace=True)
# 3. Removing Unneeded columns
population.drop(['Id', 'Id2','April 1, 2010 - Census', 'April 1, 2010 - Estimates Base'], axis=1, inplace=True)
# 4. Renaming the columns, titles are too long
population.columns = ['State','pop2010','pop2011','pop2012','pop2013','pop2014','pop2015','pop2016']
population.head(3)
# Out:
#      State  pop2010  pop2011  pop2012  pop2013  pop2014  pop2015  pop2016
# 1  Alabama  4785492  4799918  4815960  4829479  4843214  4853875  4863300
# 2   Alaska   714031   722713   731089   736879   736705   737709   741894
# 3  Arizona  6408312  6467163  6549634  6624617  6719993  6817565  6931071

# %% [markdown]
# ### (2) Homelessness DataSet: <br/>
# Converting to integers, dropping a column

# %%
## Since every column is an object ,, we need to convert Count and Year to integers
# Cleaning datasets 
# Homelessness DataSet 
# 1. converting Count to String (remove the comma) and then to an integer
homelessness['Count'] = homelessness['Count'].str.replace(',', '')
homelessness['Count'] = pd.to_numeric(homelessness['Count'])
# 2. Removing Unneeded columns
## Continuum of Care (CoC) 
homelessness.drop(['CoC Number','CoC Name','Measures'], axis=1, inplace=True)
# 3. Converting Year to dateTime and then to an integer
## so that we can check for any year we want 
homelessness['Year'] = pd.to_datetime(homelessness['Year'])
homelessness['Year'] = homelessness['Year'].dt.year
homelessness.head(20)
# Out:
#     Year State  Count
# 0   2007    AK    224
# 1   2007    AK    696
# 2   2007    AK    278
# 3   2007    AK    187
# 4   2007    AK    842
# 5   2007    AK    589
# 6   2007    AK    253
# 7   2007    AK    974
# 8   2007    AK     37
# 9   2007    AK    132
# 10  2007    AK    107
# 11  2007    AK     25
# 12  2007    AK     54
# 13  2007    AK    366
# 14  2007    AK    302
# 15  2007    AK     34
# 16  2007    AK    545
# 17  2007    AK    302
# 18  2007    AK    243
# 19  2007    AK    668

# %% [markdown]
#  <br/>
# Copying the dataset, renaming the columns
# <br/>
# ** Defining a list of the USA states.

# %%
StatesFullNames = [ 'Alaska', 'Alabama', 'Arkansas', 'Arizona', 
'California', 'Colorado', 'Connecticut', 'District of Columbia', 
'Delaware', 'Florida', 'Georgia','Guam','Hawaii', 'Iowa', 
'Idaho','Illinois', 'Indiana', 'Kansas', 'Kentucky',
'Louisiana','Massachusetts', 'Maryland', 'Maine', 'Michigan', 
'Minnesota', 'Missouri', 'Mississippi', 'Montana', 
'North Carolina', 'North Dakota', 'Nebraska', 'New Hampshire', 
'New Jersey','New Mexico', 'Nevada', 'New York', 'Ohio', 
'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 
'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 
'Texas','Utah', 'Virginia', 'Virgin Islands','Vermont', 
'Washington', 'Wisconsin', 'West Virginia', 'Wyoming']

## making a copy of the homeless dataset to use it in our map
homelessnessCopy1 = homelessness.copy()
# Removing the unneeded column in our map
## we want to show in our map, the state & # of homeless people (count)
#homelessnessCopy1.drop(['Measures'], axis=1, inplace=True)
homelessnessCopy1.columns = ['Year','StateAbbrev','CountHomeless']

# %% [markdown]
# ### (3) Data from API:  <br/>
# -Normalizing the live data be used as a dataset<br/>
# -Selecing the cost of living for each USA state for 2015 & dropping remaining columns

# %%
# Normalizing the live data called from API to be used as a dataset
CostOfLivingAll = json_normalize(dataCostOfLiving)
CostOfLivingAll
# Selecing the cost of living for each USA state for 2015 & dropping remaining columns
CostOfLivingCities2015 = json_normalize(dataCostOfLiving['2015-mid'])
CostOfLivingCities2015isUSA = CostOfLivingCities2015['country']=='United States'
CostOfLivingCities2015USA = CostOfLivingCities2015[CostOfLivingCities2015isUSA]
CostOfLivingCities2015USA.drop(['restaurant_price_index','rent_index','purchasing_power_incl_rent_index','groceries_index','cpi_and_rent_index','city_id','country'],axis=1, inplace=True )
CostOfLivingCities2015USA.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             city_name   cpi_index
# 18  San Francisco, CA  100.275779
# 19       New York, NY  100.000000
# 21       Honolulu, HI   99.033270
# 23     Washington, DC   97.717446
# 28       Brooklyn, NY   96.056669

# %%
# Removing the name of the cities 
CostOfLivingCities2015USA['city_name'] = CostOfLivingCities2015USA['city_name'].apply(lambda x: x.split(',')[-1])
CostOfLivingCities2015USA.head(3)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    city_name   cpi_index
# 18        CA  100.275779
# 19        NY  100.000000
# 21        HI   99.033270

# %%
# Selecting states with highest 'cpi_index=CostOfLiving' GroupBy CityName & nLargest Cpi_Index
CostOfLivingCities2015USA = CostOfLivingCities2015USA.groupby('city_name')['cpi_index'].apply(lambda grp: grp.nlargest(1)).reset_index()
# Sorting the values (cost of living) from largest to smallest
CostOfLivingCities2015USA = CostOfLivingCities2015USA.sort_values('cpi_index', ascending=False)[['cpi_index', 'city_name']].reset_index()
CostOfLivingCities2015USA.head(6)
# Out:
#    index   cpi_index city_name
# 0      3  100.275779        CA
# 1     24  100.000000        NY
# 2      9   99.033270        HI
# 3      6   97.717446        DC
# 4      0   91.836137        AK
# 5     34   91.700292        WA

# %%
# Dropping the new added index 
CostOfLivingCities2015USA.drop(['index'],axis=1, inplace=True )
# renaming the columns (Easier to understand)
CostOfLivingCities2015USA.columns = ['CostOfLiving','StateAbbrev']
##The names column in StateAbbrev has extra white-space surrounding the text.
CostOfLivingCities2015USA['StateAbbrev'] = CostOfLivingCities2015USA['StateAbbrev'].str.strip()

CostOfLivingCities2015USA.head()
# Out:
#    CostOfLiving StateAbbrev
# 0    100.275779          CA
# 1    100.000000          NY
# 2     99.033270          HI
# 3     97.717446          DC
# 4     91.836137          AK

# %%
CostOfLivingCities2015USA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 2 columns):
# CostOfLiving    36 non-null float64
# StateAbbrev     36 non-null object
# dtypes: float64(1), object(1)
# memory usage: 656.0+ bytes

# %% [markdown]
# -Removing the first index column instead of having <br/>
#             Year    2007    2008    2009<br/>
#             State <br/>
# We want to have
# <br/> State 2007  2008  2009
# <br/> and so on
# <br/><br/>
#
# -Adding the list of State names to HomelessnessCopy1 as a new column

# %%
# Converting the Years rows to columns and setting the # of homeless to max to avoid duplicates
homelessnessCopy1 = homelessnessCopy1.groupby(['StateAbbrev', 'Year'])['CountHomeless'].max().unstack()

homelessnessCopy1 = homelessnessCopy1.reset_index().rename_axis(None).rename_axis(None, axis=1)
# Adding the States full names column to the dataset
homelessnessCopy1['State'] = pd.Series(StatesFullNames)
homelessnessCopy1.head()
# Out:
#   StateAbbrev   2007   2008   2009   2010   2011   2012   2013   2014   2015  \
# 0          AK    974   1023   1267   1231   1223   1147   1122   1023   1208
# 1          AL   2104   2104   2273   2273   1950   1707   1469   1329   1153
# 2          AR   1822   1811   1425   1425   1276   1873   1678   1074    830
# 3          AZ   8448   7189   7889   6999   5831   6485   5889   5918   5631
# 4          CA  47862  47862  33243  33243  34622  31553  35524  34393  41174
#
#     2016       State
# 0   1105      Alaska
# 1   1228     Alabama
# 2    808    Arkansas
# 3   5702     Arizona
# 4  43854  California

# %% [markdown]
# Dropping # of homeless columns in the years (2007, 2014 and 2016)

# %%
homelessnessCopy1.drop([2007,2008,2009,2010,2011,2012,2013,2014,2016], axis=1, inplace=True)
homelessnessCopy1.head()
# Out:
#   StateAbbrev   2015       State
# 0          AK   1208      Alaska
# 1          AL   1153     Alabama
# 2          AR    830    Arkansas
# 3          AZ   5631     Arizona
# 4          CA  41174  California

# %% [markdown]
# ### (4) Race DataSet:

# %%
race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
# Location                                  52 non-null object
# White                                     52 non-null float64
# Black                                     51 non-null float64
# Hispanic                                  52 non-null float64
# Asian                                     47 non-null float64
# American Indian/Alaska Native             9 non-null float64
# Native Hawaiian/Other Pacific Islander    13 non-null float64
# Two Or More Races                         45 non-null float64
# Total                                     52 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 3.7+ KB

# %% [markdown]
# -Dropping columns with many null values & uneeded columns  <br/>
# (Note: columns with many null values do not have much effect on the data here or especially the chosen states that have higher number & percentage of homeless ) <br/>
# -Replacing the null values in the two columns that null values with the mean values of the columns

# %%
## there are NaN values--> must be replaced by 0 
## will have to delete the [ American Indian/Alaska Native & Native Hawaiian/Other Pacific Islander & Two Or More Races & Total]
## since there is no enough data about them
## No need for the 2 
race.drop(['Native Hawaiian/Other Pacific Islander', 'American Indian/Alaska Native','Total', 'Two Or More Races'], axis=1, inplace=True)

# replaceing NaN with the mean values of the columns that have null values
race['Black'].fillna(race['White'].mean(), inplace = True)
race['Asian'].fillna(race['Asian'].mean(), inplace = True)

race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
# Location    52 non-null object
# White       52 non-null float64
# Black       52 non-null float64
# Hispanic    52 non-null float64
# Asian       52 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# Now, there are No Null values

# %% [markdown]
# -Next, rounding up to 3 decimal places and multiply the numbers by 100 (to present the percentages)

# %%
# Rounding the float values to 3 decimal places
race["White"] = (race["White"].round(3))*100
race["Black"] = (race["Black"].round(3))*100
race["Hispanic"] = (race["Hispanic"].round(3))*100
race["Asian"] = (race["Asian"].round(3))*100
race.head(6)
# Out:
#         Location  White  Black  Hispanic  Asian
# 0  United States   61.0   12.0      18.0    6.0
# 1        Alabama   65.0   27.0       4.0    4.6
# 2         Alaska   58.0    3.0       6.0    7.0
# 3        Arizona   51.0    4.0      37.0    3.0
# 4       Arkansas   74.0   15.0       7.0    2.0
# 5     California   39.0    6.0      38.0   15.0

# %%
#renaming Location column 
race.rename(columns={'Location': 'State'}, inplace=True)

# %% [markdown]
# ## C. Merging the Datasets

# %% [markdown]
# ### 1. Checking the columns of the datasets to merge

# %%
homelessnessCopy2 = homelessnessCopy1.copy()
race.head()
# Out:
#            State  White  Black  Hispanic  Asian
# 0  United States   61.0   12.0      18.0    6.0
# 1        Alabama   65.0   27.0       4.0    4.6
# 2         Alaska   58.0    3.0       6.0    7.0
# 3        Arizona   51.0    4.0      37.0    3.0
# 4       Arkansas   74.0   15.0       7.0    2.0

# %%
homelessnessCopy2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 3 columns):
# StateAbbrev    54 non-null object
# 2015           54 non-null int64
# State          54 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %%
CostOfLivingCities2015USA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 2 columns):
# CostOfLiving    36 non-null float64
# StateAbbrev     36 non-null object
# dtypes: float64(1), object(1)
# memory usage: 656.0+ bytes

# %% [markdown]
# ### 2. Merging

# %%
homelessnessCopy2 = homelessnessCopy2.merge(population, on='State')
homelessnessCopy2 = homelessnessCopy2.merge(race, on='State')

homelessnessCopy2.head()
# Out:
#   StateAbbrev   2015       State   pop2010   pop2011   pop2012   pop2013  \
# 0          AK   1208      Alaska    714031    722713    731089    736879
# 1          AL   1153     Alabama   4785492   4799918   4815960   4829479
# 2          AR    830    Arkansas   2921995   2939493   2950685   2958663
# 3          AZ   5631     Arizona   6408312   6467163   6549634   6624617
# 4          CA  41174  California  37332685  37676861  38011074  38335203
#
#     pop2014   pop2015   pop2016  White  Black  Hispanic  Asian
# 0    736705    737709    741894   58.0    3.0       6.0    7.0
# 1   4843214   4853875   4863300   65.0   27.0       4.0    4.6
# 2   2966912   2977853   2988248   74.0   15.0       7.0    2.0
# 3   6719993   6817565   6931071   51.0    4.0      37.0    3.0
# 4  38680810  38993940  39250017   39.0    6.0      38.0   15.0

# %%
CostOfLivingCities2015USA.head()
# Out:
#    CostOfLiving StateAbbrev
# 0    100.275779          CA
# 1    100.000000          NY
# 2     99.033270          HI
# 3     97.717446          DC
# 4     91.836137          AK

# %%
homelessnessCopy2.drop(['pop2010','pop2011','pop2012','pop2013','pop2014','pop2016'], axis=1, inplace=True)
homelessnessCopy2.head()
# Out:
#   StateAbbrev   2015       State   pop2015  White  Black  Hispanic  Asian
# 0          AK   1208      Alaska    737709   58.0    3.0       6.0    7.0
# 1          AL   1153     Alabama   4853875   65.0   27.0       4.0    4.6
# 2          AR    830    Arkansas   2977853   74.0   15.0       7.0    2.0
# 3          AZ   5631     Arizona   6817565   51.0    4.0      37.0    3.0
# 4          CA  41174  California  38993940   39.0    6.0      38.0   15.0

# %%
homelessnessCopy2 = homelessnessCopy2.merge(CostOfLivingCities2015USA, on='StateAbbrev')
homelessnessCopy2.head()
# Out:
#   StateAbbrev   2015       State   pop2015  White  Black  Hispanic  Asian  \
# 0          AK   1208      Alaska    737709   58.0    3.0       6.0    7.0
# 1          AL   1153     Alabama   4853875   65.0   27.0       4.0    4.6
# 2          AZ   5631     Arizona   6817565   51.0    4.0      37.0    3.0
# 3          CA  41174  California  38993940   39.0    6.0      38.0   15.0
# 4          CO   5335    Colorado   5448819   69.0    4.0      21.0    3.0
#
#    CostOfLiving
# 0     91.836137
# 1     74.660620
# 2     72.588985
# 3    100.275779
# 4     75.443766

# %%
homelessnessCopy2.head(54)
# Out:
#    StateAbbrev   2015                 State   pop2015  White  Black  Hispanic  \
# 0           AK   1208                Alaska    737709   58.0    3.0       6.0
# 1           AL   1153               Alabama   4853875   65.0   27.0       4.0
# 2           AZ   5631               Arizona   6817565   51.0    4.0      37.0
# 3           CA  41174            California  38993940   39.0    6.0      38.0
# 4           CO   5335              Colorado   5448819   69.0    4.0      21.0
# 5           CT   3134           Connecticut   3584730   70.0    9.0      15.0
# 6           DC   7298  District of Columbia    670377   37.0   46.0      11.0
# 7           FL   4152               Florida  20244914   54.0   16.0      26.0
# 8           GA   5797               Georgia  10199398   52.0   31.0      10.0
# 9           HI   4903                Hawaii   1425157   19.0    2.0      10.0
# 10          IA   1975                  Iowa   3121997   85.0    3.0       8.0
# 11          ID   1211                 Idaho   1652828   84.0    1.0      13.0
# 12          IL   6786              Illinois  12839047   63.0   13.0      16.0
# 13          IN   3664               Indiana   6612768   80.0    9.0       8.0
# 14          KY   2119              Kentucky   4424611   85.0    7.0       3.0
# 15          LA   1703             Louisiana   4668960   58.0   32.0       5.0
# 16          MA   6492         Massachusetts   6784240   73.0    7.0      11.0
# 17          MD   2796              Maryland   5994983   50.0   30.0      11.0
# 18          MI   2597              Michigan   9917715   76.0   14.0       5.0
# 19          MN   3215             Minnesota   5482435   82.0    6.0       5.0
# 20          MO   1686              Missouri   6076204   80.0   11.0       4.0
# 21          NC   3021        North Carolina  10035186   62.0   21.0      11.0
# 22          NM   1342            New Mexico   2080328   38.0    2.0      44.0
# 23          NV   7509                Nevada   2883758   50.0    9.0      28.0
# 24          NY  75323              New York  19747183   58.0   14.0      18.0
# 25          OH   3320                  Ohio  11605090   79.0   12.0       4.0
# 26          OK   1300              Oklahoma   3907414   65.0    7.0      12.0
# 27          OR   5544                Oregon   4024634   74.0    2.0      15.0
# 28          PA   5998          Pennsylvania  12791904   76.0   10.0       8.0
# 29          SC   1961        South Carolina   4894834   64.0   27.0       5.0
# 30          TN   2154             Tennessee   6595056   73.0   17.0       6.0
# 31          TX   7016                 Texas  27429639   44.0   12.0      37.0
# 32          UT   2176                  Utah   2990632   81.0    1.0      13.0
# 33          VA   1204              Virginia   8367587   62.0   19.0      10.0
# 34          WA  10122            Washington   7160290   69.0    3.0      13.0
# 35          WI   3597             Wisconsin   5767891   78.0    6.0      10.0
#
#     Asian  CostOfLiving
# 0     7.0     91.836137
# 1     4.6     74.660620
# 2     3.0     72.588985
# 3    15.0    100.275779
# 4     3.0     75.443766
# 5     4.0     88.098987
# 6     5.0     97.717446
# 7     2.0     83.932619
# 8     5.0     75.506200
# 9    39.0     99.033270
# 10    2.0     63.038163
# 11    1.0     63.666096
# 12    6.0     79.141971
# 13    2.0     68.945279
# 14    4.6     68.671908
# 15    2.0     70.539588
# 16    7.0     85.968009
# 17    6.0     77.496572
# 18    3.0     79.786929
# 19    3.0     76.561871
# 20    2.0     79.157137
# 21    2.0     82.367858
# 22    1.0     66.704794
# 23    8.0     80.233393
# 24    8.0    100.000000
# 25    2.0     87.008115
# 26    2.0     69.648177
# 27    4.0     76.073219
# 28    4.0     86.735281
# 29    2.0     74.421999
# 30    2.0     68.874019
# 31    5.0     80.986109
# 32    2.0     65.328332
# 33    6.0     86.144307
# 34    8.0     91.700292
# 35    3.0     76.644054

# %%
# 1. converting Count to String (remove the comma) and then to an integer
homelessnessCopy2['pop2015'] = homelessnessCopy2['pop2015'].str.replace(',', '')
homelessnessCopy2['pop2015'] = pd.to_numeric(homelessnessCopy2['pop2015'])
homelessnessCopy2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 9 columns):
# StateAbbrev     36 non-null object
# 2015            36 non-null int64
# State           36 non-null object
# pop2015         36 non-null int64
# White           36 non-null float64
# Black           36 non-null float64
# Hispanic        36 non-null float64
# Asian           36 non-null float64
# CostOfLiving    36 non-null float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 2.8+ KB

# %%
perc2015 = 100 * (homelessnessCopy2[2015]/ homelessnessCopy2['pop2015']) 
homelessnessCopy2['perc2015'] = perc2015*100
homelessnessCopy2.head(54)
# Out:
#    StateAbbrev   2015                 State   pop2015  White  Black  Hispanic  \
# 0           AK   1208                Alaska    737709   58.0    3.0       6.0
# 1           AL   1153               Alabama   4853875   65.0   27.0       4.0
# 2           AZ   5631               Arizona   6817565   51.0    4.0      37.0
# 3           CA  41174            California  38993940   39.0    6.0      38.0
# 4           CO   5335              Colorado   5448819   69.0    4.0      21.0
# 5           CT   3134           Connecticut   3584730   70.0    9.0      15.0
# 6           DC   7298  District of Columbia    670377   37.0   46.0      11.0
# 7           FL   4152               Florida  20244914   54.0   16.0      26.0
# 8           GA   5797               Georgia  10199398   52.0   31.0      10.0
# 9           HI   4903                Hawaii   1425157   19.0    2.0      10.0
# 10          IA   1975                  Iowa   3121997   85.0    3.0       8.0
# 11          ID   1211                 Idaho   1652828   84.0    1.0      13.0
# 12          IL   6786              Illinois  12839047   63.0   13.0      16.0
# 13          IN   3664               Indiana   6612768   80.0    9.0       8.0
# 14          KY   2119              Kentucky   4424611   85.0    7.0       3.0
# 15          LA   1703             Louisiana   4668960   58.0   32.0       5.0
# 16          MA   6492         Massachusetts   6784240   73.0    7.0      11.0
# 17          MD   2796              Maryland   5994983   50.0   30.0      11.0
# 18          MI   2597              Michigan   9917715   76.0   14.0       5.0
# 19          MN   3215             Minnesota   5482435   82.0    6.0       5.0
# 20          MO   1686              Missouri   6076204   80.0   11.0       4.0
# 21          NC   3021        North Carolina  10035186   62.0   21.0      11.0
# 22          NM   1342            New Mexico   2080328   38.0    2.0      44.0
# 23          NV   7509                Nevada   2883758   50.0    9.0      28.0
# 24          NY  75323              New York  19747183   58.0   14.0      18.0
# 25          OH   3320                  Ohio  11605090   79.0   12.0       4.0
# 26          OK   1300              Oklahoma   3907414   65.0    7.0      12.0
# 27          OR   5544                Oregon   4024634   74.0    2.0      15.0
# 28          PA   5998          Pennsylvania  12791904   76.0   10.0       8.0
# 29          SC   1961        South Carolina   4894834   64.0   27.0       5.0
# 30          TN   2154             Tennessee   6595056   73.0   17.0       6.0
# 31          TX   7016                 Texas  27429639   44.0   12.0      37.0
# 32          UT   2176                  Utah   2990632   81.0    1.0      13.0
# 33          VA   1204              Virginia   8367587   62.0   19.0      10.0
# 34          WA  10122            Washington   7160290   69.0    3.0      13.0
# 35          WI   3597             Wisconsin   5767891   78.0    6.0      10.0
#
#     Asian  CostOfLiving    perc2015
# 0     7.0     91.836137   16.375021
# 1     4.6     74.660620    2.375422
# 2     3.0     72.588985    8.259547
# 3    15.0    100.275779   10.559077
# 4     3.0     75.443766    9.791113
# 5     4.0     88.098987    8.742639
# 6     5.0     97.717446  108.864117
# 7     2.0     83.932619    2.050885
# 8     5.0     75.506200    5.683669
# 9    39.0     99.033270   34.403227
# 10    2.0     63.038163    6.326079
# 11    1.0     63.666096    7.326836
# 12    6.0     79.141971    5.285439
# 13    2.0     68.945279    5.540796
# 14    4.6     68.671908    4.789122
# 15    2.0     70.539588    3.647493
# 16    7.0     85.968009    9.569237
# 17    6.0     77.496572    4.663900
# 18    3.0     79.786929    2.618547
# 19    3.0     76.561871    5.864183
# 20    2.0     79.157137    2.774759
# 21    2.0     82.367858    3.010408
# 22    1.0     66.704794    6.450906
# 23    8.0     80.233393   26.038939
# 24    8.0    100.000000   38.143668
# 25    2.0     87.008115    2.860814
# 26    2.0     69.648177    3.327009
# 27    4.0     76.073219   13.775166
# 28    4.0     86.735281    4.688903
# 29    2.0     74.421999    4.006265
# 30    2.0     68.874019    3.266083
# 31    5.0     80.986109    2.557817
# 32    2.0     65.328332    7.276054
# 33    6.0     86.144307    1.438886
# 34    8.0     91.700292   14.136299
# 35    3.0     76.644054    6.236248

# %% [markdown]
# ## D. Drawing

# %%
Colorscl = [[0.0, 'rgb(230, 240, 255)'],[0.2, 'rgb(179, 209, 255)'],
            [0.4, 'rgb(102, 163, 255)'], [0.6, 'rgb(0, 102, 255)'],
            [0.8, 'rgb(0, 71, 179)'],[1.0, 'rgb(0, 31, 77)']]

text = [
    f'{t} <br> Percentage of Homeless: {r:.2f}% <br> Percentage of Black People: {j:.2f}%'
    for t, r,j in zip(homelessnessCopy2['State'], homelessnessCopy2['perc2015'],homelessnessCopy2['Black'])
]

data = [
    go.Scatter(
        x=homelessnessCopy2['perc2015'],
        y=homelessnessCopy2['CostOfLiving'],
        text=text,
        mode='markers',
        marker=dict(
         #   sizemin=5,
            size=15,
            colorscale=Colorscl,
            showscale=True,
            color=homelessnessCopy2['Black'],
            line=dict(color='black', width=1.2)
        ))
]

figure = go.Figure(
    data=data,
    layout=go.Layout(    
        xaxis=dict(title='Percentage of Homeless',
           #        range=[0, 105]
                  ),
        yaxis=dict(title='Cost Of Living',
                       range=[0, 105],
                          dtick=10),
        title='Percentage of Homeless vs Cost Of Living Colored by Percentage of Black Individuals, 2015'
    ))

iplot(figure)
# Out:
# <div id="5628a9d6-34e4-4a14-8ed2-c690edb0ba2c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5628a9d6-34e4-4a14-8ed2-c690edb0ba2c", [{"marker": {"color": [3.0, 27.0, 4.0, 6.0, 4.0, 9.0, 46.0, 16.0, 31.0, 2.0, 3.0, 1.0, 13.0, 9.0, 7.000000000000001, 32.0, 7.000000000000001, 30.0, 14.000000000000002, 6.0, 11.0, 21.0, 2.0, 9.0, 14.000000000000002, 12.0, 7.000000000000001, 2.0, 10.0, 27.0, 17.0, 12.0, 1.0, 19.0, 3.0, 6.0], "colorscale": [[0.0, "rgb(230, 240, 255)"], [0.2, "rgb(179, 209, 255)"], [0.4, "rgb(102, 163, 255)"], [0.6, "rgb(0, 102, 255)"], [0.8, "rgb(0, 71, 179)"], [1.0, "rgb(0, 31, 77)"]], "line": {"color": "black", "width": 1.2}, "showscale": true, "size": 15}, "mode": "markers", "text": ["Alaska <br> Percentage of Homeless: 16.38% <br> Percentage of Black People: 3.00%", "Alabama <br> Percentage of Homeless: 2.38% <br> Percentage of Black People: 27.00%", "Arizona <br> Percentage of Homeless: 8.26% <br> Percentage of Black People: 4.00%", "California <br> Percentage of Homeless: 10.56% <br> Percentage of Black People: 6.00%", "Colorado <br> Percentage of Homeless: 9.79% <br> Percentage of Black People: 4.00%", "Connecticut <br> Percentage of Homeless: 8.74% <br> Percentage of Black People: 9.00%", "District of Columbia <br> Percentage of Homeless: 108.86% <br> Percentage of Black People: 46.00%", "Florida <br> Percentage of Homeless: 2.05% <br> Percentage of Black People: 16.00%", "Georgia <br> Percentage of Homeless: 5.68% <br> Percentage of Black People: 31.00%", "Hawaii <br> Percentage of Homeless: 34.40% <br> Percentage of Black People: 2.00%", "Iowa <br> Percentage of Homeless: 6.33% <br> Percentage of Black People: 3.00%", "Idaho <br> Percentage of Homeless: 7.33% <br> Percentage of Black People: 1.00%", "Illinois <br> Percentage of Homeless: 5.29% <br> Percentage of Black People: 13.00%", "Indiana <br> Percentage of Homeless: 5.54% <br> Percentage of Black People: 9.00%", "Kentucky <br> Percentage of Homeless: 4.79% <br> Percentage of Black People: 7.00%", "Louisiana <br> Percentage of Homeless: 3.65% <br> Percentage of Black People: 32.00%", "Massachusetts <br> Percentage of Homeless: 9.57% <br> Percentage of Black People: 7.00%", "Maryland <br> Percentage of Homeless: 4.66% <br> Percentage of Black People: 30.00%", "Michigan <br> Percentage of Homeless: 2.62% <br> Percentage of Black People: 14.00%", "Minnesota <br> Percentage of Homeless: 5.86% <br> Percentage of Black People: 6.00%", "Missouri <br> Percentage of Homeless: 2.77% <br> Percentage of Black People: 11.00%", "North Carolina <br> Percentage of Homeless: 3.01% <br> Percentage of Black People: 21.00%", "New Mexico <br> Percentage of Homeless: 6.45% <br> Percentage of Black People: 2.00%", "Nevada <br> Percentage of Homeless: 26.04% <br> Percentage of Black People: 9.00%", "New York <br> Percentage of Homeless: 38.14% <br> Percentage of Black People: 14.00%", "Ohio <br> Percentage of Homeless: 2.86% <br> Percentage of Black People: 12.00%", "Oklahoma <br> Percentage of Homeless: 3.33% <br> Percentage of Black People: 7.00%", "Oregon <br> Percentage of Homeless: 13.78% <br> Percentage of Black People: 2.00%", "Pennsylvania <br> Percentage of Homeless: 4.69% <br> Percentage of Black People: 10.00%", "South Carolina <br> Percentage of Homeless: 4.01% <br> Percentage of Black People: 27.00%", "Tennessee <br> Percentage of Homeless: 3.27% <br> Percentage of Black People: 17.00%", "Texas <br> Percentage of Homeless: 2.56% <br> Percentage of Black People: 12.00%", "Utah <br> Percentage of Homeless: 7.28% <br> Percentage of Black People: 1.00%", "Virginia <br> Percentage of Homeless: 1.44% <br> Percentage of Black People: 19.00%", "Washington <br> Percentage of Homeless: 14.14% <br> Percentage of Black People: 3.00%", "Wisconsin <br> Percentage of Homeless: 6.24% <br> Pe ...
